# %% [markdown]
# # The Best Offer

# %% [markdown]
# I want to find the best supplier to work with, I will figure out what factors would help determine that would determine which is the best Supplier to work with, what is their most Popular product, what product could be better and is there a way to make more of the least purchase product and still be profitable?

# %% [markdown]
# ### Importing What will be needed for this project.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from acquire import df
from acquire import sup3

# %% [markdown]
# ## Who is the most profitable Supplier?

# %% [markdown]
# I will be importing portions of the file for every question asked.

# %%
from acquire import supplier_revenue

# %%
supplier_revenue()

# %% [markdown]
# ### Supplier 3 has the highest sales generated.

# %% [markdown]
# ## What is the most popular product?

# %%
from acquire import revenue

# %%
revenue()

# %% [markdown]
# ### Cosmetics are the biggest revenue earning product.

# %% [markdown]
# ## What is the most popular product?

# %%
from acquire import number_sold

# %%
number_sold()

# %% [markdown]
# ### Cosmetics are not quite as popular as the other two, and yet it would be possible to sell more hair care products as well as cosmetics.

# %% [markdown]
# ## It would surely be easy to reproduce them, right?

# %%
from acquire import defect

# %%
defect()

# %% [markdown]
# ### It may not be as feasible to reproduce cosmetics, but hair care can be replicated with less defects.

# %% [markdown]
# ##  If it were allowed to produce more, how likely will there be more defects?

# %%
from acquire import defect_predict

# %%
defect_predict()

# %% [markdown]
# ### After a test, it would seem to be slightly less likely to produce defects for hair care after the defect rate of the original production, but would appear to be about the same after some validation.

# %% [markdown]
# # In conclusion, Supplier 3 would be the best to work with as they make the more popular products and generate higher revenue. They could generate more if they were able to create more haircare and cosmetic products, though it's more likely to be better to make more hair products.
